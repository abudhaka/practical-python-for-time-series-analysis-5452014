# %% [markdown]
# # Simple linear regression

# %% [markdown]
# ## Load data

# %%
path = '../../data/FRED/CPI_MR_2008_D.parquet'

# %%
import pandas as pd
df = pd.read_parquet(path)

df
# Out:
#                  CPI     MR
# date
# 2007-12-28  2.726036  6.020
# 2008-01-11  2.671887  5.585
# ...              ...    ...
# 2008-07-25  3.076253  6.520
# 2008-08-08  3.076197  6.495
#
# [17 rows x 2 columns]

# %% [markdown]
# ## Linear regression
# ### Visualize relationship

# %% [markdown]
# ### Feature selection

# %%
# Out:
# date
# 2007-12-28    6.020
# 2008-01-11    5.585
#               ...
# 2008-07-25    6.520
# 2008-08-08    6.495
# Name: MR, Length: 17, dtype: float64

# %%
# Out:
#                  CPI
# date
# 2007-12-28  2.726036
# 2008-01-11  2.671887
# ...              ...
# 2008-07-25  3.076253
# 2008-08-08  3.076197
#
# [17 rows x 1 columns]

# %%
# Out:
#             const       CPI
# date
# 2007-12-28    1.0  2.726036
# 2008-01-11    1.0  2.671887
# ...           ...       ...
# 2008-07-25    1.0  3.076253
# 2008-08-08    1.0  3.076197
#
# [17 rows x 2 columns]

# %% [markdown]
# ### Fit model

# %%
# Out:
# [                     0                 1                    2         3
#  0               Model:               OLS      Adj. R-squared:     0.799
#  1  Dependent Variable:                MR                 AIC:  -20.1985
#  2                Date:  2025-09-29 06:57                 BIC:  -18.5321
#  3    No. Observations:                17      Log-Likelihood:    12.099
#  4            Df Model:                 1         F-statistic:     64.46
#  5        Df Residuals:                15  Prob (F-statistic):  8.24e-07
#  6           R-squared:             0.811               Scale:  0.015984,
#            Coef.  Std.Err.         t         P>|t|    [0.025    0.975]
#  const  1.591036  0.561563  2.833229  1.258617e-02  0.394093  2.787979
#  CPI    1.586528  0.197611  8.028545  8.241145e-07  1.165330  2.007725,
#                  0      1                  2      3
#  0        Omnibus:  1.094     Durbin-Watson:  1.527
#  1  Prob(Omnibus):  0.579  Jarque-Bera (JB):  0.173
#  2           Skew:  0.204          Prob(JB):  0.917
#  3       Kurtosis:  3.280     Condition No.:     58]

# %% [markdown]
# ### Interpret results

# %%
# Out:
#                      0                 1                    2         3
# 0               Model:               OLS      Adj. R-squared:     0.799
# 1  Dependent Variable:                MR                 AIC:  -20.1985
# 2                Date:  2025-09-29 06:57                 BIC:  -18.5321
# 3    No. Observations:                17      Log-Likelihood:    12.099
# 4            Df Model:                 1         F-statistic:     64.46
# 5        Df Residuals:                15  Prob (F-statistic):  8.24e-07
# 6           R-squared:             0.811               Scale:  0.015984

# %%
# Out:
#           Coef.  Std.Err.         t         P>|t|    [0.025    0.975]
# const  1.591036  0.561563  2.833229  1.258617e-02  0.394093  2.787979
# CPI    1.586528  0.197611  8.028545  8.241145e-07  1.165330  2.007725

# %%
# Out:
#                 0      1                  2      3
# 0        Omnibus:  1.094     Durbin-Watson:  1.527
# 1  Prob(Omnibus):  0.579  Jarque-Bera (JB):  0.173
# 2           Skew:  0.204          Prob(JB):  0.917
# 3       Kurtosis:  3.280     Condition No.:     58

# %%
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.799
# Dependent Variable: y                AIC:                -20.1985
# Date:               2025-09-29 06:57 BIC:                -18.5321
# No. Observations:   17               Log-Likelihood:     12.099
# Df Model:           1                F-statistic:        64.46
# Df Residuals:       15               Prob (F-statistic): 8.24e-07
# R-squared:          0.811            Scale:              0.015984
# --------------------------------------------------------------------
#           Coef.     Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     1.5910      0.5616    2.8332    0.0126    0.3941    2.7880
# x1        1.5865      0.1976    8.0285    0.0000    1.1653    2.0077
# -----------------------------------------------------------------
# Omnibus:              1.094        Durbin-Watson:           2.323
# Prob(Omnibus):        0.579        Jarque-Bera (JB):        0.173
# Skew:                 0.204        Prob(JB):                0.917
# Kurtosis:             3.280        Condition No.:           58
# =================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the
# errors is correctly specified.
# """

# %% [markdown]
# ## Diagnostics and assumptions

# %% [markdown]
# ### Residuals

# %% [markdown]
# #### Calculation

# %%
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.799
# Dependent Variable: MR               AIC:                -20.1985
# Date:               2025-09-29 06:57 BIC:                -18.5321
# No. Observations:   17               Log-Likelihood:     12.099
# Df Model:           1                F-statistic:        64.46
# Df Residuals:       15               Prob (F-statistic): 8.24e-07
# R-squared:          0.811            Scale:              0.015984
# --------------------------------------------------------------------
#           Coef.     Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     1.5910      0.5616    2.8332    0.0126    0.3941    2.7880
# CPI       1.5865      0.1976    8.0285    0.0000    1.1653    2.0077
# -----------------------------------------------------------------
# Omnibus:              1.094        Durbin-Watson:           1.527
# Prob(Omnibus):        0.579        Jarque-Bera (JB):        0.173
# Skew:                 0.204        Prob(JB):                0.917
# Kurtosis:             3.280        Condition No.:           58
# =================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the
# errors is correctly specified.
# """

# %%
# Out:
#                  CPI     MR   MR_pred  MR_resid
# date
# 2007-12-28  2.726036  6.020  5.915967  0.104033
# 2008-01-11  2.671887  5.585  5.830058 -0.245058
# ...              ...    ...       ...       ...
# 2008-07-25  3.076253  6.520  6.471596  0.048404
# 2008-08-08  3.076197  6.495  6.471507  0.023493
#
# [17 rows x 4 columns]

# %%
# Out:
# np.float64(0.8112199074697531)

# %%
# Out:
# np.float64(0.8112199074697531)

# %%
# Out:
#                  CPI     MR    fitted  residuals
# date
# 2007-12-28  2.726036  6.020  5.915967   0.104033
# 2008-01-11  2.671887  5.585  5.830058  -0.245058
# ...              ...    ...       ...        ...
# 2008-07-25  3.076253  6.520  6.471596   0.048404
# 2008-08-08  3.076197  6.495  6.471507   0.023493
#
# [17 rows x 4 columns]

# %% [markdown]
# ### Linearity and homoscedasticity

# %% [markdown]
# #### Plot

# %% [markdown]
# #### Test: Breusch-Pagan test (Homoscedasticity)

# %%
# Out:
# Breusch-Pagan p-value: 0.085

# %% [markdown]
# ### Normality of residuals

# %% [markdown]
# #### Plot

# %% [markdown]
# #### Test: Shapiro-Wilkx

# %%
# Out:
# Shapiro-Wilk test: W=0.978, p-value=0.937

# %% [markdown]
# ### Independence

# %% [markdown]
# #### Plot

# %% [markdown]
# #### Test: Durbin-Watson

# %%
# Out:
# Durbin-Watson: 1.526

# %% [markdown]
# ## Robust model

# %%
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.798
# Dependent Variable: MR               AIC:                -20.1713
# Date:               2025-09-22 13:06 BIC:                -18.5049
# No. Observations:   17               Log-Likelihood:     12.086
# Df Model:           1                F-statistic:        64.33
# Df Residuals:       15               Prob (F-statistic): 8.34e-07
# R-squared:          0.811            Scale:              0.016010
# --------------------------------------------------------------------
#           Coef.     Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     1.6467      0.5552    2.9659    0.0096    0.4633    2.8300
# CPI       1.5661      0.1953    8.0206    0.0000    1.1499    1.9823
# -----------------------------------------------------------------
# Omnibus:              1.044        Durbin-Watson:           1.526
# Prob(Omnibus):        0.593        Jarque-Bera (JB):        0.159
# Skew:                 0.198        Prob(JB):                0.924
# Kurtosis:             3.259        Condition No.:           58
# =================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the
# errors is correctly specified.
# """

# %%
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.798
# Dependent Variable: MR               AIC:                -20.1713
# Date:               2025-09-22 13:06 BIC:                -18.5049
# No. Observations:   17               Log-Likelihood:     12.086
# Df Model:           1                F-statistic:        67.72
# Df Residuals:       15               Prob (F-statistic): 6.07e-07
# R-squared:          0.811            Scale:              0.016010
# --------------------------------------------------------------------
#           Coef.     Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     1.6467      0.5632    2.9239    0.0105    0.4463    2.8471
# CPI       1.5661      0.1903    8.2291    0.0000    1.1605    1.9718
# -----------------------------------------------------------------
# Omnibus:              1.044        Durbin-Watson:           1.526
# Prob(Omnibus):        0.593        Jarque-Bera (JB):        0.159
# Skew:                 0.198        Prob(JB):                0.924
# Kurtosis:             3.259        Condition No.:           58
# =================================================================
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation
# robust (HAC) using 1 lags and without small sample correction
# """
