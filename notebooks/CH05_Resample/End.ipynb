# %% [markdown]
# # Temporal resampling

# %% [markdown]
# ## Load data

# %%
path = '../../data/FRED/FRED_joined.parquet'

# %%
import pandas as pd
df = pd.read_parquet(path)

df
# Out:
#             CPI   MR  FFR  INF10  UNRT
# date
# 1948-01-01  NaN  NaN  NaN    NaN  3.40
# 1948-02-01  NaN  NaN  NaN    NaN  3.80
# ...         ...  ...  ...    ...   ...
# 2025-09-11 3.42 6.35 4.33   2.34  4.30
# 2025-09-12 3.42 6.35 4.33   2.36  4.30
#
# [4697 rows x 5 columns]

# %%
df.plot()

# %% [markdown]
# ## Steps

# %% [markdown]
# ### Resample

# %%
r = df.resample('5YE').agg(func='mean')
r
# Out:
#                  CPI      MR30       FFR     INF10      UNRT
# date
# 1948-12-31       NaN       NaN       NaN       NaN  3.750000
# 1953-12-31       NaN       NaN       NaN       NaN  4.098333
# ...              ...       ...       ...       ...       ...
# 2023-12-31  4.047612  4.693787  2.052181  2.330040  4.568386
# 2028-12-31  3.822416  6.734608  4.783370  2.302849  4.103548
#
# [17 rows x 5 columns]

# %% [markdown]
# ### Visualize

# %% [markdown]
# #### Plot

# %%
r.plot()

# %%
import plotly.graph_objects as go

fig = go.Figure()
for c in r.columns:
    fig.add_trace(go.Scatter(x=r.index, y=r[c], fill="tozeroy", name=c))

fig

# %% [markdown]
# #### Heatmatrix

# %%
(r
 .style
    .background_gradient(cmap='Greens', axis=None)
    .format(precision=2, thousands=',')
    .format_index(formatter=lambda x: x.strftime('%Y'))
)
# Out:
# <style type="text/css">
# #T_db87b_row0_col0, #T_db87b_row0_col1, #T_db87b_row0_col2, #T_db87b_row0_col3, #T_db87b_row1_col0, #T_db87b_row1_col1, #T_db87b_row1_col2, #T_db87b_row1_col3, #T_db87b_row2_col0, #T_db87b_row2_col1, #T_db87b_row2_col3, #T_db87b_row3_col0, #T_db87b_row3_col1, #T_db87b_row3_col3, #T_db87b_row4_col1, #T_db87b_row4_col3, #T_db87b_row5_col3, #T_db87b_row6_col3, #T_db87b_row7_col3, #T_db87b_row8_col3, #T_db87b_row9_col3, #T_db87b_row10_col3, #T_db87b_row11_col3, #T_db87b_row12_col3, #T_db87b_row13_col3, #T_db87b_row14_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_db87b_row0_col4 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_db87b_row1_col4, #T_db87b_row16_col4 {
#   background-color: #bde5b6;
#   color: #000000;
# }
# #T_db87b_row2_col2 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_db87b_row2_col4 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_db87b_row3_col2 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_db87b_row3_col4 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_db87b_row4_col0 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_db87b_row4_col2 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_db87b_row4_col4 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_db87b_row5_col0 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_db87b_row5_col1 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_db87b_row5_col2 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_db87b_row5_col4, #T_db87b_row10_col2, #T_db87b_row10_col4 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_db87b_row6_col0 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T_db87b_row6_col1 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_db87b_row6_col2, #T_db87b_row11_col1 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_db87b_row6_col4 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_db87b_row7_col0 {
#   background-color: #3ca559;
#   color: #f1f1f1;
# }
# #T_db87b_row7_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_db87b_row7_col2 {
#   background-color: #006c2c;
#   color: #f1f1f1;
# }
# #T_db87b_row7_col4 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_db87b_row8_col0 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_db87b_row8_col1 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_db87b_row8_col2 {
#   background-color: #60ba6c;
#   color: #f1f1f1;
# }
# #T_db87b_row8_col4 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_db87b_row9_col0 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_db87b_row9_col1 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_db87b_row9_col2 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_db87b_row9_col4 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_db87b_row10_col0 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_db87b_row10_col1 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_db87b_row11_col0 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_db87b_row11_col2 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_db87b_row11_col4 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_db87b_row12_col0 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_db87b_row12_col1 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_db87b_row12_col2 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_db87b_row12_col4 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_db87b_row13_col0 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_db87b_row13_col1 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_db87b_row13_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_db87b_row13_col4 {
#   background-color: #4aaf61;
#   color: #f1f1f1;
# }
# #T_db87b_row14_col0 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_db87b_row14_col1, #T_db87b_row15_col0 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_db87b_row14_col2 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_db87b_row14_col4 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_db87b_row15_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_db87b_row15_col2 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_db87b_row15_col3, #T_db87b_row16_col3 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_db87b_row15_col4 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_db87b_row16_col0 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_db87b_row16_col1 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_db87b_row16_col2 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# </style>
# <table id="T_db87b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db87b_level0_col0" class="col_heading level0 col0" >CPI</th>
#       <th id="T_db87b_level0_col1" class="col_heading level0 col1" >MR30</th>
#       <th id="T_db87b_level0_col2" class="col_heading level0 col2" >FFR</th>
#       <th id="T_db87b_level0_col3" class="col_heading level0 col3" >INF10</th>
#       <th id="T_db87b_level0_col4" class="col_heading level0 col4" >UNRT</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db87b_level0_row0" class="row_heading level0 row0" >1948</th>
#       <td id="T_db87b_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_db87b_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_db87b_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_db87b_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_db87b_row0_col4" class="data row0 col4" >3.75</td>
#     </tr>
#     <tr>
#       <th id="T_db87b_level0_row1" class="row_heading level0 row1" >1953</th>
#       <td id="T_db87b_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_db87b_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_db87b_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_db87b_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_db87b_row1_col4" class="data row1 col4" >4.10</td>
#     </tr>
#     <tr>
#       <th id="T_db87b_level0_row2" class="row_heading level0 row2" >1958</th>
#       <td id="T_db87b_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_db87b_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_db87b_row2_col2" class="data row2 col2" >2.15</td>
#       <td id="T_db87b_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_db87b_row2_col4" class="data row2 col4" >5.04</td>
#     </tr>
#     <tr>
#       <th id="T_db87b_level0_row3" class="row_heading level0 row3" >1963</th>
#       <td id="T_db87b_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_db87b_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_db87b_row3_col2" class="data row3 col2" >2.87</td>
#       <td id="T_db87b_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_db87b_row3_col4" class="data row3 col4" >5.78</td>
#     </tr>
#     <tr>
#       <th id="T_db87b_level0_row4" class="row_heading level0 row4" >1968</th>
#       <td id="T_db87b_row4_col0" class="data row4 col0" >4.60</td>
#       <td id="T_db87b_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_db87b_row4_col2" class="data row4 col2" >4.51</td>
#       <td id="T_db87b_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_db87b_row4_col4" class="data row4 col4" >4.17</td>
#     </tr>
#     <tr>
#       <th id="T_db87b_level0_row5" class="row_heading level0 row5" >1973</th>
#       <td id="T_db87b_row5_col0" class="data row5 col0" >4.28</td>
#       <td id="T_db87b_row5_col1" class="data row5 col1" >7.67</td>
#       <td id="T_db87b_row5_col2" class="data row5 col2" >6.34</td>
#       <td id="T_db87b_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_db87b_row5_col4" class="data row5 col4" >5.29</td>
#     </tr>
#     <tr>
#       <th id="T_db87b_level0_row6" class="row_heading level0 row6" >1978</th>
#       <td id="T_db87b_row6_col0" class="data row6 col0" >8.13</td>
#       <td id="T_db87b_r

# %% [markdown]
# #### Heatmatrix with plotly

# %%
r = df.resample('5YE').agg(func='mean')

ranking = r.sum().sort_values(ascending=False).index.tolist()
r = r[ranking].T

r
# Out:
# date   1948-12-31  1953-12-31  1958-12-31  1963-12-31  1968-12-31  1973-12-31  \
# UNRT         3.75    4.098333    5.045000    5.778333    4.171667    5.286250
# MR30          NaN         NaN         NaN         NaN         NaN    7.666686
# FFR           NaN         NaN    2.154444    2.872500    4.512500    6.343500
# CPI           NaN         NaN         NaN         NaN    4.599479    4.275978
# INF10         NaN         NaN         NaN         NaN         NaN         NaN
#
# date   1978-12-31  1983-12-31  1988-12-31  1993-12-31  1998-12-31  2003-12-31  \
# UNRT     7.003205    8.000796    6.653355    6.437380    5.284026    4.950639
# MR30     9.112003   14.197803   11.400543    9.083003    7.733067    6.960911
# FFR      6.955929   12.456752    7.868498    5.851629    5.245351    3.547029
# CPI      8.133798    9.238669    4.727408    4.461052    2.986932    2.714608
# INF10         NaN         NaN         NaN         NaN         NaN         NaN
#
# date   2008-12-31  2013-12-31  2018-12-31  2023-12-31  2028-12-31
# UNRT     5.153045    8.644231    4.902396    4.568386    4.103548
# MR30     6.098365    4.364567    4.038546    4.693787    6.734608
# FFR      3.278590    0.136282    0.698962    2.052181    4.783370
# CPI      2.608544    1.670438    2.271824    4.047612    3.822416
# INF10         NaN         NaN         NaN    2.330040    2.302849

# %%
import plotly.express as px
px.imshow(r)

# %%
r = df.resample('ME').agg(func='mean').T
r
# Out:
# date   1948-01-31  1948-02-29  1948-03-31  1948-04-30  1948-05-31  1948-06-30  \
# CPI           NaN         NaN         NaN         NaN         NaN         NaN
# MR30          NaN         NaN         NaN         NaN         NaN         NaN
# FFR           NaN         NaN         NaN         NaN         NaN         NaN
# INF10         NaN         NaN         NaN         NaN         NaN         NaN
# UNRT          3.4         3.8         4.0         3.9         3.5         3.6
#
# date   1948-07-31  1948-08-31  1948-09-30  1948-10-31  ...  2024-12-31  \
# CPI           NaN         NaN         NaN         NaN  ...    3.688551
# MR30          NaN         NaN         NaN         NaN  ...    6.729280
# FFR           NaN         NaN         NaN         NaN  ...    4.408261
# INF10         NaN         NaN         NaN         NaN  ...    2.303478
# UNRT          3.6         3.9         3.8         3.7  ...    4.052174
#
# date   2025-01-31  2025-02-28  2025-03-31  2025-04-30  2025-05-31  2025-06-30  \
# CPI      3.573260    3.393325    3.219096    3.168310    3.221006    3.351314
# MR30     6.959478    6.854683    6.657758    6.728455    6.817424    6.819167
# FFR      4.330000    4.330000    4.330000    4.330000    4.330000    4.330000
# INF10    2.397609    2.425476    2.335909    2.240227    2.313864    2.299773
# UNRT     4.047826    4.147619    4.200000    4.200000    4.152273    4.147727
#
# date   2025-07-31  2025-08-31  2025-09-30
# CPI      3.419811    3.419811    3.419811
# MR30     6.722609    6.600857    6.447200
# FFR      4.330000    4.330000    4.330000
# INF10    2.381739    2.381905    2.373000
# UNRT     4.247826    4.300000    4.300000
#
# [5 rows x 933 columns]

# %%
px.imshow(r)
